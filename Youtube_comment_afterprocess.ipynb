# %% [markdown]
# <a href="https://colab.research.google.com/github/RiyaNusrat/Public-Sentiment-on-Social-Media/blob/main/Youtube_comment_afterprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import re                 # Importing re module to work with regular expressions

# %%
data= pd.read_excel('/content/drive/MyDrive/Social Media Data/YT comments data.xlsx')

# %%
data.head()
# Out:
#               Timestamp         Username      VideoID  \
# 0  2024-08-02T19:19:07Z    @thedeshbhakt  jCL2P85f_98
# 1  2024-08-02T19:20:22Z        @tx_Fahim  jCL2P85f_98
# 2  2024-08-02T19:21:24Z       @arfazhxss  jCL2P85f_98
# 3  2024-08-02T19:21:38Z      @Shajib-n8h  jCL2P85f_98
# 4  2024-08-02T19:23:34Z  @paponislam1756  jCL2P85f_98
#
#                                              Comment           Timestamp.1
# 0  Watch Part 1 - What Is 'Dictator' Sheikh Hasin...  2024-08-02T19:19:07Z
# 1                   Thanks sir for covering this 🇧🇩❤  2024-08-02T19:20:22Z
# 2                                     Thank you! 🇧🇩🔴  2024-08-02T19:21:24Z
# 3  @@thedeshbhakt We all will also remember-\n\nA...  2024-08-02T19:21:38Z
# 4  Sir বিকল্প আছে Bangladesh  1 st Prime minister...  2024-08-02T19:23:34Z

# %%
data.tail()
# Out:
#                    Timestamp                 Username      VideoID  \
# 127045  2024-07-23T10:36:39Z  @alitheonekhatarnak5163  TcYXzgXfuts
# 127046  2024-07-23T10:37:55Z           @codswallop164  TcYXzgXfuts
# 127047  2024-07-23T10:52:59Z     @deltaechomusicnh555  TcYXzgXfuts
# 127048  2024-07-23T11:05:27Z          @Tanisha178-j5r  TcYXzgXfuts
# 127049  2024-07-23T11:10:00Z           @codswallop164  TcYXzgXfuts
#
#                                                   Comment
# 127045                                They aren't allowed
# 127046  @alitheonekhatarnak5163\nSo it's a nation of b...
# 127047  Pakistan itself isn't even a liberal nation, a...
# 127048  it's still a taboo in many countries. you can'...
# 127049  @Tanisha178-j5r\nThe why should the rest of th...

# %%
data.describe()
# Out:
#                    Timestamp          Username      VideoID          Comment  \
# count                 127050            127035       127050           127027
# unique                 89250             88887            7           101620
# top     2024-08-02T17:02:37Z  @Radical.atheist  jCL2P85f_98  #stepdownhasina
# freq                      14                94        59741              892
#
#                  Timestamp.1
# count                 127050
# unique                 89305
# top     2024-08-02T17:02:37Z
# freq                      13

# %%
data = data.drop(columns= ['Timestamp.1'])

# %%
data.head()
# Out:
#               Timestamp         Username      VideoID  \
# 0  2024-08-02T19:19:07Z    @thedeshbhakt  jCL2P85f_98
# 1  2024-08-02T19:20:22Z        @tx_Fahim  jCL2P85f_98
# 2  2024-08-02T19:21:24Z       @arfazhxss  jCL2P85f_98
# 3  2024-08-02T19:21:38Z      @Shajib-n8h  jCL2P85f_98
# 4  2024-08-02T19:23:34Z  @paponislam1756  jCL2P85f_98
#
#                                              Comment
# 0  Watch Part 1 - What Is 'Dictator' Sheikh Hasin...
# 1                   Thanks sir for covering this 🇧🇩❤
# 2                                     Thank you! 🇧🇩🔴
# 3  @@thedeshbhakt We all will also remember-\n\nA...
# 4  Sir বিকল্প আছে Bangladesh  1 st Prime minister...

# %%
data.isnull().sum()
# Out:
# Timestamp     0
# Username     15
# VideoID       0
# Comment      23
# dtype: int64

# %%
data.shape
# Out:
# (127050, 4)

# %%
newdata = data.dropna()

# %% [markdown]
# ## Dataset after dropping null values

# %%
newdata.isnull().sum()
# Out:
# Timestamp    0
# Username     0
# VideoID      0
# Comment      0
# dtype: int64

# %%
newdata.shape
# Out:
# (127012, 4)

# %%
newdata.duplicated(subset='Comment').sum()
# Out:
# np.int64(25404)

# %% [markdown]
# ## After removing duplicate comments

# %%
no_dupe_comments= newdata.drop_duplicates(subset='Comment', keep='first')

# %%
no_dupe_comments.shape
# Out:
# (101608, 4)

# %%
# !pip install clean-text
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171031 sha256=cd425eddd5026c2a911f8b2e91c4c64a3c854c012d2c83eb26800f2cdd685eee
#   Stored in directory: /root/.cache/pip/wheels/bd/22/e5/b69726d5e1a19795ecd3b3e7464b16c0f1d019aa94ff1c8578
# Successfully built emoji
# ...

# %%
from cleantext import clean
# !pip install emoji
import emoji

# %%
import re

# Compile regex patterns
emoji_pattern = re.compile(
    "["
    u"\U0001F600-\U0001F64F"  # emoticons
    u"\U0001F300-\U0001F5FF"  # symbols & pictographs
    u"\U0001F680-\U0001F6FF"  # transport & map symbols
    u"\U0001F1E0-\U0001F1FF"  # flags
    u"\U00002700-\U000027BF"  # dingbats
    u"\U0001F900-\U0001F9FF"  # supplemental symbols
    u"\U00002600-\U000026FF"  # miscellaneous symbols
    "]+", flags=re.UNICODE
)

url_pattern = re.compile(r"http\S+|www\S+")
email_pattern = re.compile(r"\S+@\S+")
phone_pattern = re.compile(r"\+?\d[\d\s\-]{7,}\d")
currency_pattern = re.compile(r"[৳$€£¥₹]")

# Cleaning function
def clean_comment(text):
    text = str(text)
    text = emoji_pattern.sub('', text)          # Remove emojis
    text = url_pattern.sub('', text)            # Remove URLs
    text = email_pattern.sub('', text)          # Remove emails
    text = phone_pattern.sub('', text)          # Remove phone numbers
    text = currency_pattern.sub('', text)       # Remove currency symbols
    text = re.sub(r'\s+', ' ', text).strip()    # Remove extra whitespace
    return text

# Apply to the 'comment' column
no_dupe_comments.loc[:, 'Comment'] = no_dupe_comments['Comment'].apply(clean_comment)

# %%
no_dupe_comments.head()
# Out:
#               Timestamp         Username      VideoID  \
# 0  2024-08-02T19:19:07Z    @thedeshbhakt  jCL2P85f_98
# 1  2024-08-02T19:20:22Z        @tx_Fahim  jCL2P85f_98
# 2  2024-08-02T19:21:24Z       @arfazhxss  jCL2P85f_98
# 3  2024-08-02T19:21:38Z      @Shajib-n8h  jCL2P85f_98
# 4  2024-08-02T19:23:34Z  @paponislam1756  jCL2P85f_98
#
#                                              Comment
# 0  watch part 1 - what is 'dictator' sheikh hasin...
# 1                     thanks sir for covering this ️
# 2                                         thank you!
# 3  we all will also remember- ahad (4) the bullet...
# 4   sir bangladesh 1 st prime minister son shoel taj

# %%
no_dupe_comments.tail()
# Out:
#                    Timestamp                 Username      VideoID  \
# 124017  2024-07-23T10:36:39Z  @alitheonekhatarnak5163  TcYXzgXfuts
# 124018  2024-07-23T10:37:55Z           @codswallop164  TcYXzgXfuts
# 124019  2024-07-23T10:52:59Z     @deltaechomusicnh555  TcYXzgXfuts
# 124020  2024-07-23T11:05:27Z          @Tanisha178-j5r  TcYXzgXfuts
# 124021  2024-07-23T11:10:00Z           @codswallop164  TcYXzgXfuts
#
#                                                   Comment
# 124017                                they aren't allowed
# 124018  @alitheonekhatarnak5163 so it's a nation of ba...
# 124019  pakistan itself isn't even a liberal nation, a...
# 124020  it's still a taboo in many countries. you can'...
# 124021  @tanisha178-j5r the why should the rest of the...

# %%
# Step 1: Convert all values to string, remove 'Z' if present
no_dupe_comments.loc[:, 'Timestamp'] = no_dupe_comments['Timestamp'].astype(str).str.replace('Z', '', regex=False)

# Step 2: Convert the cleaned string to datetime
no_dupe_comments.loc[:, 'Timestamp'] = pd.to_datetime(no_dupe_comments['Timestamp'], errors='coerce')

# Step 3: Extract date and time
no_dupe_comments.loc[:, 'Date'] = no_dupe_comments['Timestamp'].dt.date
no_dupe_comments.loc[:, 'Time'] = no_dupe_comments['Timestamp'].dt.time

# %%
no_dupe_comments.head()
# Out:
#             Timestamp         Username      VideoID  \
# 0 2024-08-02 19:19:07    @thedeshbhakt  jCL2P85f_98
# 1 2024-08-02 19:20:22        @tx_Fahim  jCL2P85f_98
# 2 2024-08-02 19:21:24       @arfazhxss  jCL2P85f_98
# 3 2024-08-02 19:21:38      @Shajib-n8h  jCL2P85f_98
# 4 2024-08-02 19:23:34  @paponislam1756  jCL2P85f_98
#
#                                              Comment        Date      Time
# 0  Watch Part 1 - What Is 'Dictator' Sheikh Hasin...  2024-08-02  19:19:07
# 1                       Thanks sir for covering this  2024-08-02  19:20:22
# 2                                         Thank you!  2024-08-02  19:21:24
# 3  We all will also remember- Ahad (4) The bullet...  2024-08-02  19:21:38
# 4  Sir বিকল্প আছে Bangladesh 1 st Prime minister ...  2024-08-02  19:23:34

# %%
no_dupe_comments = no_dupe_comments.drop(columns= ['Timestamp'])

# %%
no_dupe_comments.head()
# Out:
#           Username      VideoID  \
# 0    @thedeshbhakt  jCL2P85f_98
# 1        @tx_Fahim  jCL2P85f_98
# 2       @arfazhxss  jCL2P85f_98
# 3      @Shajib-n8h  jCL2P85f_98
# 4  @paponislam1756  jCL2P85f_98
#
#                                              Comment        Date      Time
# 0  Watch Part 1 - What Is 'Dictator' Sheikh Hasin...  2024-08-02  19:19:07
# 1                       Thanks sir for covering this  2024-08-02  19:20:22
# 2                                         Thank you!  2024-08-02  19:21:24
# 3  We all will also remember- Ahad (4) The bullet...  2024-08-02  19:21:38
# 4  Sir বিকল্প আছে Bangladesh 1 st Prime minister ...  2024-08-02  19:23:34

# %%
no_dupe_comments = no_dupe_comments.drop(columns= ['Username'])
